# %% [markdown]
# ### 2024: Week 27 - Tour de France special
#
# July 03, 2024
#
# Created by: Carl Allchin
#
# The Tour de France starts this week. The world's biggest and most popular cycling race is celebrated and we wanted to mark the occasion.
#
# Here at Preppin' Data, we have our own cycling brand: Allchains. It's a fake company so we've never had any success. As a British cycling fan, a lot of my joy in the sport has come from Mark Cavendish's wins that have made him the real world most successful stage winner in the Tour de France's history.
#
# This Preppin' uses real world data to create a data source so you can explore what it takes to become the greatest sprinter in Tour de France history. In this challenge you will need to combine the Tour de Frances Cavendish has raced, the stages he's won, what types of stages they were and where he finished overall in the race that year (if he finished at all).
#
# ### Inputs
#
# There are four data sets:
#
# 1. Stages — All the stages in the years that Cavedish raced the Tour.
#
# ![1](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEj4X43750LKEgcpxrO37zaJHnqNOnXU0cYw3PGWmedIq6ixqcrprNDLvEvgPynL944CpWA7PPXR1YPOU-YnEgM0XQ7s2WqQ_YBf-QZSdsrC0fNc7gyN_qkw4ozZTkKP7WQtTtLyAYxdK9T3ZJDuVmfcNDixFBUfgGVUmpnevxB8YVddPQFLD_Nxpvdgt-5I/s1926/Screenshot%202024-06-27%20at%2012.15.50.png)
#
# 2. Stage Type — The type of stages raced
#
# ![2](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhGh6F4dWbNf81xJ-qOiKR_e_rnPCjCIt_goND9heLP3ZaJdj02ckRIMz3sqwerGZd9F6FZ4DKogpNInbVMZrNVwEuRuxe6_gTV-T07HOm3SInFD3OOQAKFlIlhKbQPt0hUqYKoUne4nHUULWxzzLqpHHaPAKQ_iuzIjJqA6plPipUjx3F2bB8xnoF1sAmP/s542/Screenshot%202024-06-27%20at%2012.15.59.png)
#
# 3. Wins — All of Cavendish's career wins
#
# ![3](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiiaTo3n60JmqHwEJodYXmXIoCMsATPlpxxP3VCx0HOc1pc6LWZBzuP4IJd1ix3ytWLtXQ0J-fqySjLN0G4UKBqvMfNqXzWii5n7FR_r1bbdSgTfbBORNPefdBkQAorUbF10Jd6Pxph_FinLnU9twFR85LrHHmIQjylQ9V0mCpF16BarbZBm8qVHplvVwzC/s1456/Screenshot%202024-06-27%20at%2012.16.10.png)
#
# 4. Grand Tour Starts — All the Grand Tours (there's 3 major races in a year) Cavendish has made and where he's finished
#
# ![4](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhkRLuKCwAxpTjGzRy9hV2yxx-J4Fa4n3LMxe2b9BGpmjc989wQsDP_3zFEPMFuF8GVHE1acJL6EQEwUq0fSLFtyXV6AdLDsRkWU5_8ck7EHThc3Bs-Npx9-iqENa3qycm3tlStJpl0xdDh8h68ZX3XiBu-aldzXqVJhcaNT_3EqcRyPQmb9f1bdyn2U3E_/s1572/Screenshot%202024-06-27%20at%2012.16.21.png)
#
# ### Requirements
#
# - Input the data sets
# - Join together the Stages and Stage Type table
# - Create a field called 'Time Trial ?' to determine if the stage was a Time Trial
# - Time trials are shown as either Individual Time Trials (ITT)s or Team Time Trials (TTT)s
# - Create an 'Origin - Destination' field and a 'Stage Number' field
# - For the Stage Number, capture the Prologue stage as 0
# - Join in the 'Wins' data. Keep all of the stages and add additional details of the stages Cavendish has won
# - You'll need to prepare the data to be able to join to the data set you've built thus far
# - Remove all duplicate fields created within the Joins
# - Input the Grand Tour Starts but keep only the Tour de France starts
# - Rename:
# - GC to 'General Classification Finishing Position'
# - Points to 'Points Finishing Position'
# - Join the races started to the overall data set to provide the overall finishing position and points finishing position
# - Create a 'Stages Won?' field from the Stage Number Won to a 'Yes' when Cavendish won the stage or NULL if not.
# - Output the data
#
# ### Output
#
# ![5](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEjeSouF6pYsNP5lEALMI23vWrar857_RmPp7XK6bI88Oi58kGwA-Y1niv9XxxL2MKL3KV6E4B-1GuL8XNJMQBZ5wUbUMF2DRaVNwGB3z_uwdq59OAAtuiZInFz1t64_srE2aQon5BiQThvYh60dVpOzNkp-aV48xd9CsYbhyeNWbkuFJRO5Y2JnJXQuZNbk/s966/Screenshot%202024-06-27%20at%2014.05.56.png)
#
#
# 9 data fields:
# - Stage Won?
# - Stage Number
# - Origin - Destination
# - Time Trial?
# - General Classification
# - Points Finishing
# - Year
# - KM
# - Stage Type
#
# 294 rows (295 rows incl. headers)

# %%
import pandas as pd

# Read the Excel file
excel_file = pd.ExcelFile('PD 2024 Wk 27 Input.xlsx')

# List all sheet names
sheet_names = excel_file.sheet_names
print(sheet_names)
# Out:
# ['Wins', 'Stage Type', 'Stages', 'Grand Tour Starts']

# %%
# Read the 'Wins' sheet into a DataFrame
wins_df = pd.read_excel(excel_file, sheet_name='Wins')
wins_df.head()
# Out:
#     Nr                                               Race  Class       Date  \
# 0  164                          Tour de Hongrie | Stage 2  2.Pro 2024-05-09
# 1  163                            Tour Colombia | Stage 4    2.1 2024-02-09
# 2  162                           Giro d'Italia | Stage 21  2.UWT 2023-05-28
# 3  161  National Championships Great Britain ME - Road...     NC 2022-06-26
# 4  160                            Giro d'Italia | Stage 3  2.UWT 2022-05-08
#
#   Category
# 0       ME
# 1       ME
# 2       ME
# 3       ME
# 4       ME

# %%
# Read the 'Stage Type' sheet into a DataFrame
stage_type_df = pd.read_excel(excel_file, sheet_name='Stage Type')
stage_type_df
# Out:
#    Stage Type ID                Stage Type
# 0              1                      Flat
# 1              2        Hills, flat finish
# 2              3      Hills, uphill finish
# 3              4    Mountains, flat finish
# 4              5  Mountains, uphill finish

# %%
# Read the 'Stages' sheet into a DataFrame
stage_df = pd.read_excel(excel_file, sheet_name='Stages')
stage_df
# Out:
#      Year       Date        Day  Unnamed: 3  \
# 0    2007 2024-07-07   Saturday         NaN
# 1    2007 2024-07-08     Sunday         NaN
# 2    2007 2024-07-09     Monday         NaN
# 3    2007 2024-07-10    Tuesday         NaN
# 4    2007 2024-07-11  Wednesday         NaN
# ..    ...        ...        ...         ...
# 317  2023 2024-07-19  Wednesday         NaN
# 318  2023 2024-07-20   Thursday         NaN
# 319  2023 2024-07-21     Friday         NaN
# 320  2023 2024-07-22   Saturday         NaN
# 321  2023 2024-07-23     Sunday         NaN
#
#                                                 Stage     KM  Stage Type
# 0                          Prologue | London - London    7.9         1.0
# 1                       Stage 1 | London - Canterbury  203.0         1.0
# 2                          Stage 2 | Dunkerque - Gent  168.5         1.0
# 3                       Stage 3 | Waregem - Compiegne  236.5         1.0
# 4                Stage 4 | Villers-Cotterets - Joigny  193.0         1.0
# ..                                                ...    ...         ...
# 317  Stage 17 | Saint-Gervais Mont-Blanc - Courchevel  165.7         4.0
# 318             Stage 18 | Moûtiers - Bourg-en-Bresse  184.9         1.0
# 319          Stage 19 | Moirans-en-Montagne - Poligny  172.8         2.0
# 320                 Stage 20 | Belfort - Le Markstein  133.5         4.0
# 321      Stage 21 | Saint-Quentin-en-Yvelines - Paris  115.1         1.0
#
# [322 rows x 7 columns]

# %%
# Read the 'Grand Tour Starts' sheet into a DataFrame
tour_starts_df = pd.read_excel(excel_file, sheet_name='Grand Tour Starts')
tour_starts_df
# Out:
#      #  Season       Grand tour   GC  Points  Mountains  Youth  \
# 0   23    2023   Tour de France  DNF     NaN        NaN    NaN
# 1   22    2023    Giro d'Italia  119     4.0        NaN    NaN
# 2   21    2022    Giro d'Italia  145     3.0        NaN    NaN
# 3   20    2021   Tour de France  139     1.0        NaN    NaN
# 4   19    2018   Tour de France  DNF     NaN        NaN    NaN
# 5   18    2017   Tour de France  DNF     NaN        NaN    NaN
# 6   17    2016   Tour de France  DNF     NaN        NaN    NaN
# 7   16    2015   Tour de France  142     4.0        NaN    NaN
# 8   15    2014   Tour de France  DNF     NaN        NaN    NaN
# 9   14    2013   Tour de France  148     2.0        NaN    NaN
# 10  13    2013    Giro d'Italia  127     1.0        NaN    NaN
# 11  12    2012   Tour de France  142     4.0        NaN    NaN
# 12  11    2012    Giro d'Italia  145     2.0        NaN    NaN
# 13  10    2011  Vuelta a España  DNF     NaN        NaN    NaN
# 14   9    2011   Tour de France  130     1.0        NaN    NaN
# 15   8    2011    Giro d'Italia  DNF     NaN        NaN    NaN
# 16   7    2010  Vuelta a España  144     1.0        NaN    NaN
# 17   6    2010   Tour de France  151     2.0        NaN   30.0
# 18   5    2009   Tour de France  127     2.0        NaN   26.0
# 19   4    2009    Giro d'Italia  DNF     NaN        NaN    NaN
# 20   3    2008   Tour de France  DNF     NaN        NaN    NaN
# 21   2    2008    Giro d'Italia  132     4.0        NaN   34.0
# 22   1    2007   Tour de France  DNF     NaN        NaN    NaN
#
#    Best stage result
# 0                  2
# 1                  1
# 2                  1
# 3             1 (4x)
# 4                  8
# 5                  4
# 6             1 (4x)
# 7                  1
# 8                192
# 9             1 (2x)
# 10            1 (5x)
# 11            1 (3x)
# 12            1 (3x)
# 13               158
# 14            1 (5x)
# 15            1 (3x)
# 16            1 (4x)
# 17            1 (5x)
# 18            1 (6x)
# 19            1 (4x)
# 20            1 (4x)
# 21            1 (2x)
# 22                 9

# %%
# Merge stage_df with stage_type_df on 'Stage Type'
merged_df = stage_df.merge(stage_type_df, left_on='Stage Type', right_on='Stage Type ID', how='left')

# Drop the 'Stage Type ID' column as it is no longer needed
merged_df.drop(columns=['Stage Type ID'], inplace=True)

merged_df
# Out:
#      Year       Date        Day  Unnamed: 3  \
# 0    2007 2024-07-07   Saturday         NaN
# 1    2007 2024-07-08     Sunday         NaN
# 2    2007 2024-07-09     Monday         NaN
# 3    2007 2024-07-10    Tuesday         NaN
# 4    2007 2024-07-11  Wednesday         NaN
# ..    ...        ...        ...         ...
# 317  2023 2024-07-19  Wednesday         NaN
# 318  2023 2024-07-20   Thursday         NaN
# 319  2023 2024-07-21     Friday         NaN
# 320  2023 2024-07-22   Saturday         NaN
# 321  2023 2024-07-23     Sunday         NaN
#
#                                                 Stage     KM  Stage Type_x  \
# 0                          Prologue | London - London    7.9           1.0
# 1                       Stage 1 | London - Canterbury  203.0           1.0
# 2                          Stage 2 | Dunkerque - Gent  168.5           1.0
# 3                       Stage 3 | Waregem - Compiegne  236.5           1.0
# 4                Stage 4 | Villers-Cotterets - Joigny  193.0           1.0
# ..                                                ...    ...           ...
# 317  Stage 17 | Saint-Gervais Mont-Blanc - Courchevel  165.7           4.0
# 318             Stage 18 | Moûtiers - Bourg-en-Bresse  184.9           1.0
# 319          Stage 19 | Moirans-en-Montagne - Poligny  172.8           2.0
# 320                 Stage 20 | Belfort - Le Markstein  133.5           4.0
# 321      Stage 21 | Saint-Quentin-en-Yvelines - Paris  115.1           1.0
#
#                Stage Type_y
# 0                      Flat
# 1                      Flat
# 2                      Flat
# 3                      Flat
# 4                      Flat
# ..                      ...
# 317  Mountains, flat finish
# 318                    Flat
# 319      Hills, flat finish
# 320  Mountains, flat finish
# 321                    Flat
#
# [322 rows x 8 columns]

# %%
merged_df['Time Trial ?'] = merged_df['Stage'].str.contains(r'\(ITT\)|\(TTT\)')
merged_df
# Out:
#      Year       Date        Day  Unnamed: 3  \
# 0    2007 2024-07-07   Saturday         NaN
# 1    2007 2024-07-08     Sunday         NaN
# 2    2007 2024-07-09     Monday         NaN
# 3    2007 2024-07-10    Tuesday         NaN
# 4    2007 2024-07-11  Wednesday         NaN
# ..    ...        ...        ...         ...
# 317  2023 2024-07-19  Wednesday         NaN
# 318  2023 2024-07-20   Thursday         NaN
# 319  2023 2024-07-21     Friday         NaN
# 320  2023 2024-07-22   Saturday         NaN
# 321  2023 2024-07-23     Sunday         NaN
#
#                                                 Stage     KM  Stage Type_x  \
# 0                          Prologue | London - London    7.9           1.0
# 1                       Stage 1 | London - Canterbury  203.0           1.0
# 2                          Stage 2 | Dunkerque - Gent  168.5           1.0
# 3                       Stage 3 | Waregem - Compiegne  236.5           1.0
# 4                Stage 4 | Villers-Cotterets - Joigny  193.0           1.0
# ..                                                ...    ...           ...
# 317  Stage 17 | Saint-Gervais Mont-Blanc - Courchevel  165.7           4.0
# 318             Stage 18 | Moûtiers - Bourg-en-Bresse  184.9           1.0
# 319          Stage 19 | Moirans-en-Montagne - Poligny  172.8           2.0
# 320                 Stage 20 | Belfort - Le Markstein  133.5           4.0
# 321      Stage 21 | Saint-Quentin-en-Yvelines - Paris  115.1           1.0
#
#                Stage Type_y  Time Trial ?
# 0                      Flat         False
# 1                      Flat         False
# 2                      Flat         False
# 3                      Flat         False
# 4                      Flat         False
# ..                      ...           ...
# 317  Mountains, flat finish         False
# 318                    Flat         False
# 319      Hills, flat finish         False
# 320  Mountains, flat finish         False
# 321                    Flat         False
#
# [322 rows x 9 columns]

# %%
# filter out the rows where 'Stage' contains 'restday'
filtered_df = merged_df[~merged_df['Stage'].str.contains('restday', case=False)]
filtered_df
# Out:
#      Year       Date        Day  Unnamed: 3  \
# 0    2007 2024-07-07   Saturday         NaN
# 1    2007 2024-07-08     Sunday         NaN
# 2    2007 2024-07-09     Monday         NaN
# 3    2007 2024-07-10    Tuesday         NaN
# 4    2007 2024-07-11  Wednesday         NaN
# ..    ...        ...        ...         ...
# 317  2023 2024-07-19  Wednesday         NaN
# 318  2023 2024-07-20   Thursday         NaN
# 319  2023 2024-07-21     Friday         NaN
# 320  2023 2024-07-22   Saturday         NaN
# 321  2023 2024-07-23     Sunday         NaN
#
#                                                 Stage     KM  Stage Type_x  \
# 0                          Prologue | London - London    7.9           1.0
# 1                       Stage 1 | London - Canterbury  203.0           1.0
# 2                          Stage 2 | Dunkerque - Gent  168.5           1.0
# 3                       Stage 3 | Waregem - Compiegne  236.5           1.0
# 4                Stage 4 | Villers-Cotterets - Joigny  193.0           1.0
# ..                                                ...    ...           ...
# 317  Stage 17 | Saint-Gervais Mont-Blanc - Courchevel  165.7           4.0
# 318             Stage 18 | Moûtiers - Bourg-en-Bresse  184.9           1.0
# 319          Stage 19 | Moirans-en-Montagne - Poligny  172.8           2.0
# 320                 Stage 20 | Belfort - Le Markstein  133.5           4.0
# 321      Stage 21 | Saint-Quentin-en-Yvelines - Paris  115.1           1.0
#
#                Stage Type_y  Time Trial ?
# 0                      Flat         False
# 1                      Flat         False
# 2                      Flat         False
# 3                      Flat         False
# 4                      Flat         False
# ..                      ...           ...
# 317  Mountains, flat finish         False
# 318                    Flat         False
# 319      Hills, flat finish         False
# 320  Mountains, flat finish         False
# 321                    Flat         False
#
# [294 rows x 9 columns]

# %%
# Split the 'Stage' column into 'Stage Number' and 'Origin - Destination'
filtered_df[['Stage Number', 'Origin - Destination']] = filtered_df['Stage'].str.split('|', expand=True)

# Strip any leading or trailing whitespace from the new columns
filtered_df['Stage Number'] = filtered_df['Stage Number'].str.strip()
filtered_df['Origin - Destination'] = filtered_df['Origin - Destination'].str.strip()

# Remove 'Stage' text and keep only the number, replace 'Prologue' with 0
filtered_df['Stage Number'] = filtered_df['Stage Number'].str.replace('Stage ', '', regex=False)
filtered_df['Stage Number'] = filtered_df['Stage Number'].replace('Prologue', '0')

# Remove any non-numeric characters from 'Stage Number'
filtered_df['Stage Number'] = filtered_df['Stage Number'].str.extract('(\d+)')[0]

# Convert 'Stage Number' to numeric
filtered_df['Stage Number'] = pd.to_numeric(filtered_df['Stage Number'])
# Keep only the necessary columns
filtered_df = filtered_df[['Stage Number', 'Origin - Destination', 'Time Trial ?', 'Year', 'KM', 'Stage Type_y']]
filtered_df
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:13: SyntaxWarning: invalid escape sequence '\d'
#   filtered_df['Stage Number'] = filtered_df['Stage Number'].str.extract('(\d+)')[0]
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['Stage Number', 'Origin - Destination']] = filtered_df['Stage'].str.split('|', expand=True)
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['Stage Number', 'Origin - Destination']] = filtered_df['Stage'].str.split('|', expand=True)
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage Number'] = filtered_df['Stage Number'].str.strip()
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Origin - Destination'] = filtered_df['Origin - Destination'].str.strip()
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage Number'] = filtered_df['Stage Number'].str.replace('Stage ', '', regex=False)
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage Number'] = filtered_df['Stage Number'].replace('Prologue', '0')
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage Number'] = filtered_df['Stage Number'].str.extract('(\d+)')[0]
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3424159045.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage Number'] = pd.to_numeric(filtered_df['Stage Number'])
#      Stage Number                   Origin - Destination  Time Trial ?  Year  \
# 0               0                        London - London         False  2007
# 1               1                    London - Canterbury         False  2007
# 2               2                       Dunkerque - Gent         False  2007
# 3               3                    Waregem - Compiegne         False  2007
# 4               4             Villers-Cotterets - Joigny         False  2007
# ..            ...                                    ...           ...   ...
# 317            17  Saint-Gervais Mont-Blanc - Courchevel         False  2023
# 318            18             Moûtiers - Bourg-en-Bresse         False  2023
# 319            19          Moirans-en-Montagne - Poligny         False  2023
# 320            20                 Belfort - Le Markstein         False  2023
# 321            21      Saint-Quentin-en-Yvelines - Paris         False  2023
#
#         KM            Stage Type_y
# 0      7.9                    Flat
# 1    203.0                    Flat
# 2    168.5                    Flat
# 3    236.5                    Flat
# 4    193.0                    Flat
# ..     ...                     ...
# 317  165.7  Mountains, flat finish
# 318  184.9                    Flat
# 319  172.8      Hills, flat finish
# 320  133.5  Mountains, flat finish
# 321  115.1                    Flat
#
# [294 rows x 6 columns]

# %%
# Split the 'Race' column into 'Race Name' and 'Stage'
wins_df[['Race Name', 'Stage']] = wins_df['Race'].str.split('|', expand=True)

# Strip any leading or trailing whitespace from the new columns
wins_df['Race Name'] = wins_df['Race Name'].str.strip()
wins_df['Stage'] = wins_df['Stage'].str.strip()

wins_df.head()
# Out:
#     Nr                                               Race  Class       Date  \
# 0  164                          Tour de Hongrie | Stage 2  2.Pro 2024-05-09
# 1  163                            Tour Colombia | Stage 4    2.1 2024-02-09
# 2  162                           Giro d'Italia | Stage 21  2.UWT 2023-05-28
# 3  161  National Championships Great Britain ME - Road...     NC 2022-06-26
# 4  160                            Giro d'Italia | Stage 3  2.UWT 2022-05-08
#
#   Category                                          Race Name     Stage
# 0       ME                                    Tour de Hongrie   Stage 2
# 1       ME                                      Tour Colombia   Stage 4
# 2       ME                                      Giro d'Italia  Stage 21
# 3       ME  National Championships Great Britain ME - Road...      None
# 4       ME                                      Giro d'Italia   Stage 3

# %%
wins_df = wins_df.dropna(subset=['Stage'])
# Ensure 'Stage' column is treated as string
wins_df['Stage'] = wins_df['Stage'].astype(str)

# Replace 'Prologue' with '0' in the 'Stage' column
wins_df['Stage'] = wins_df['Stage'].replace('Prologue', '0')

# Remove any non-numeric characters from 'Stage' column
wins_df['Stage'] = wins_df['Stage'].str.extract('(\d+)')[0]

# Convert 'Stage' column to numeric
wins_df['Stage'] = pd.to_numeric(wins_df['Stage'])

wins_df
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\3092802039.py:9: SyntaxWarning: invalid escape sequence '\d'
#   wins_df['Stage'] = wins_df['Stage'].str.extract('(\d+)')[0]
#       Nr                                               Race  Class       Date  \
# 0    164                          Tour de Hongrie | Stage 2  2.Pro 2024-05-09
# 1    163                            Tour Colombia | Stage 4    2.1 2024-02-09
# 2    162                           Giro d'Italia | Stage 21  2.UWT 2023-05-28
# 4    160                            Giro d'Italia | Stage 3  2.UWT 2022-05-08
# 6    158                                 UAE Tour | Stage 2  2.UWT 2022-02-21
# ..   ...                                                ...    ...        ...
# 158    6               Volta Ciclista a Catalunya | Stage 6   2.PT 2007-05-26
# 159    5               Volta Ciclista a Catalunya | Stage 2   2.PT 2007-05-22
# 160    4  4 Jours de Dunkerque - Tour du Nord-Pas-de-Cal...   2.HC 2007-05-13
# 161    3  4 Jours de Dunkerque - Tour du Nord-Pas-de-Cal...   2.HC 2007-05-10
# 163    1  Course Cycliste de Solidarnosc et des Champion...    2.1 2006-06-29
#
#     Category                                          Race Name  Stage
# 0         ME                                    Tour de Hongrie      2
# 1         ME                                      Tour Colombia      4
# 2         ME                                      Giro d'Italia     21
# 4         ME                                      Giro d'Italia      3
# 6         ME                                           UAE Tour      2
# ..       ...                                                ...    ...
# 158       ME                         Volta Ciclista a Catalunya      6
# 159       ME                         Volta Ciclista a Catalunya      2
# 160       ME  4 Jours de Dunkerque - Tour du Nord-Pas-de-Calais      6
# 161       ME  4 Jours de Dunkerque - Tour du Nord-Pas-de-Calais      3
# 163       ME  Course Cycliste de Solidarnosc et des Champion...      3
#
# [147 rows x 7 columns]

# %%
# Filter the wins_df to include only 'Tour de France' records
tour_de_france_wins_df = wins_df[wins_df['Race Name'] == 'Tour de France']

# Extract year from 'Date' as 'Year'
tour_de_france_wins_df['Year'] = tour_de_france_wins_df['Date'].dt.year
# Keep only the necessary columns
tour_de_france_wins_df = tour_de_france_wins_df[['Stage', 'Year']]
tour_de_france_wins_df
# Out:
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\2616803008.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tour_de_france_wins_df['Year'] = tour_de_france_wins_df['Date'].dt.year
#      Stage  Year
# 9       13  2021
# 10      10  2021
# 11       6  2021
# 12       4  2021
# 22      14  2016
# 23       6  2016
# 24       3  2016
# 25       1  2016
# 30       7  2015
# 59      13  2013
# 60       5  2013
# 78      20  2012
# 79      18  2012
# 80       2  2012
# 92      21  2011
# 93      15  2011
# 94      11  2011
# 95       7  2011
# 96       5  2011
# 104     20  2010
# 105     18  2010
# 106     11  2010
# 107      6  2010
# 108      5  2010
# 116     21  2009
# 117     19  2009
# 118     11  2009
# 119     10  2009
# 120      3  2009
# 121      2  2009
# 141     13  2008
# 142     12  2008
# 143      8  2008
# 144      5  2008

# %%
# Perform the join
final_df = filtered_df.merge(tour_de_france_wins_df, left_on=['Stage Number', 'Year'], right_on=['Stage', 'Year'], how='left')
final_df
# Out:
#      Stage Number                   Origin - Destination  Time Trial ?  Year  \
# 0               0                        London - London         False  2007
# 1               1                    London - Canterbury         False  2007
# 2               2                       Dunkerque - Gent         False  2007
# 3               3                    Waregem - Compiegne         False  2007
# 4               4             Villers-Cotterets - Joigny         False  2007
# ..            ...                                    ...           ...   ...
# 289            17  Saint-Gervais Mont-Blanc - Courchevel         False  2023
# 290            18             Moûtiers - Bourg-en-Bresse         False  2023
# 291            19          Moirans-en-Montagne - Poligny         False  2023
# 292            20                 Belfort - Le Markstein         False  2023
# 293            21      Saint-Quentin-en-Yvelines - Paris         False  2023
#
#         KM            Stage Type_y  Stage
# 0      7.9                    Flat    NaN
# 1    203.0                    Flat    NaN
# 2    168.5                    Flat    NaN
# 3    236.5                    Flat    NaN
# 4    193.0                    Flat    NaN
# ..     ...                     ...    ...
# 289  165.7  Mountains, flat finish    NaN
# 290  184.9                    Flat    NaN
# 291  172.8      Hills, flat finish    NaN
# 292  133.5  Mountains, flat finish    NaN
# 293  115.1                    Flat    NaN
#
# [294 rows x 7 columns]

# %%
# Rename 'Stage Type_y' to 'Stage Type'
final_df.rename(columns={'Stage Type_y': 'Stage Type'}, inplace=True)
final_df
# Out:
#      Stage Number                   Origin - Destination  Time Trial ?  Year  \
# 0               0                        London - London         False  2007
# 1               1                    London - Canterbury         False  2007
# 2               2                       Dunkerque - Gent         False  2007
# 3               3                    Waregem - Compiegne         False  2007
# 4               4             Villers-Cotterets - Joigny         False  2007
# ..            ...                                    ...           ...   ...
# 289            17  Saint-Gervais Mont-Blanc - Courchevel         False  2023
# 290            18             Moûtiers - Bourg-en-Bresse         False  2023
# 291            19          Moirans-en-Montagne - Poligny         False  2023
# 292            20                 Belfort - Le Markstein         False  2023
# 293            21      Saint-Quentin-en-Yvelines - Paris         False  2023
#
#         KM              Stage Type  Stage
# 0      7.9                    Flat    NaN
# 1    203.0                    Flat    NaN
# 2    168.5                    Flat    NaN
# 3    236.5                    Flat    NaN
# 4    193.0                    Flat    NaN
# ..     ...                     ...    ...
# 289  165.7  Mountains, flat finish    NaN
# 290  184.9                    Flat    NaN
# 291  172.8      Hills, flat finish    NaN
# 292  133.5  Mountains, flat finish    NaN
# 293  115.1                    Flat    NaN
#
# [294 rows x 7 columns]

# %%
tour_de_france_starts_df = tour_starts_df[tour_starts_df['Grand tour'] == 'Tour de France']
tour_de_france_starts_df.rename(columns={'GC': 'General Classification Finishing Position', 'Points': 'Points Finishing Position'}, inplace=True)
tour_de_france_starts_df = tour_de_france_starts_df[['Season', 'General Classification Finishing Position', 'Points Finishing Position']]
tour_de_france_starts_df
# Out:
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_16464\765610339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tour_de_france_starts_df.rename(columns={'GC': 'General Classification Finishing Position', 'Points': 'Points Finishing Position'}, inplace=True)
#     Season General Classification Finishing Position  \
# 0     2023                                       DNF
# 3     2021                                       139
# 4     2018                                       DNF
# 5     2017                                       DNF
# 6     2016                                       DNF
# 7     2015                                       142
# 8     2014                                       DNF
# 9     2013                                       148
# 11    2012                                       142
# 14    2011                                       130
# 17    2010                                       151
# 18    2009                                       127
# 20    2008                                       DNF
# 22    2007                                       DNF
#
#     Points Finishing Position
# 0                         NaN
# 3                         1.0
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         4.0
# 8                         NaN
# 9                         2.0
# 11                        4.0
# 14                        1.0
# 17                        2.0
# 18                        2.0
# 20                        NaN
# 22                        NaN

# %%
# Perform the join
final_df = final_df.merge(tour_de_france_starts_df, left_on='Year', right_on='Season', how='inner')

# Drop the redundant 'Season' column
final_df.drop(columns=['Season'], inplace=True)
# Create 'Stages Won?' field
final_df['Stages Won?'] = final_df['Stage'].apply(lambda x: 'Yes' if pd.notnull(x) else None)
# Drop the redundant 'Stage' column
final_df.drop(columns=['Stage'], inplace=True)

output = final_df
output
# Out:
#      Stage Number                   Origin - Destination  Time Trial ?  Year  \
# 0               0                        London - London         False  2007
# 1               1                    London - Canterbury         False  2007
# 2               2                       Dunkerque - Gent         False  2007
# 3               3                    Waregem - Compiegne         False  2007
# 4               4             Villers-Cotterets - Joigny         False  2007
# ..            ...                                    ...           ...   ...
# 289            17  Saint-Gervais Mont-Blanc - Courchevel         False  2023
# 290            18             Moûtiers - Bourg-en-Bresse         False  2023
# 291            19          Moirans-en-Montagne - Poligny         False  2023
# 292            20                 Belfort - Le Markstein         False  2023
# 293            21      Saint-Quentin-en-Yvelines - Paris         False  2023
#
#         KM              Stage Type General Classification Finishing Position  \
# 0      7.9                    Flat                                       DNF
# 1    203.0                    Flat                                       DNF
# 2    168.5                    Flat                                       DNF
# 3    236.5                    Flat                                       DNF
# 4    193.0                    Flat                                       DNF
# ..     ...                     ...                                       ...
# 289  165.7  Mountains, flat finish                                       DNF
# 290  184.9                    Flat                                       DNF
# 291  172.8      Hills, flat finish                                       DNF
# 292  133.5  Mountains, flat finish                                       DNF
# 293  115.1                    Flat                                       DNF
#
#      Points Finishing Position Stages Won?
# 0                          NaN        None
# 1                          NaN        None
# 2                          NaN        None
# 3                          NaN        None
# 4                          NaN        None
# ..                         ...         ...
# 289                        NaN        None
# 290                        NaN        None
# 291                        NaN        None
# 292                        NaN        None
# 293                        NaN        None
#
# [294 rows x 9 columns]
