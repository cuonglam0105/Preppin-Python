# %% [markdown]
# # 2024: Week 10 - Preppin' for Pulse
#
# March 06, 2024
#
# Challenge by: Jenny Martin
#
# Tableau Product Manager, Libby Knell has challenged us to create a Preppin' Data challenge that gets data in shape for working with the newly released Tableau Pulse. Pulse empowers every employee to make better, faster decisions by tracking a metric’s current value, compared to the past — so what does this mean for the shape of our data? Currently, Pulse works best with:
#
# - Data that is up to date and recent - the last 1 or 2 years and changes regularly - daily or weekly preferable
# - Data that is complete, without gaps
# - Data that is as granular as possible
# - The names of fields are human readable - let’s not use acronyms that lack context!
# - String values in the data are consistently named
#
# Chin & Beard Suds Co are excited to get started using Tableau Pulse so their employees can make smarter decisions for their flagship store. Their store manager is always on the go and works off their phone daily. With the insights Pulse provides, they’ll be better able to keep track of which products are selling well and might need to be restocked sooner than anticipated. Even better, digests on Email and Slack, as well as Tableau Pulse on Tableau Mobile, meets them where they are so they can stay on top of their daily changing data!
#
# ### Inputs
#
# 1. Transaction Data
#
# ![1](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEjWZcwoM_0o6KlJkIwhyQhOWmiTjwBbZFt5gv9auf-1bTxnycz44lyjqQYb9vxI-cHlyXd6nBqCNY4j3dS7IFRIaXY_JycFwwfdFECG1s8LnOCt-6VsVqW5oV1Et6F7SNHnsf_2ln8sklULngxZtZVGdMnUGDye3m11heNDMkVqSVQlg8uIeusNG-nGD64C/s1047/Screenshot%202024-02-28%20120535.png)
#
# 2. Product Table
#
# ![2](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEh0nQ0aERFOnpB_u_QKzNDgcjl9pv0F7K6c_AjyawfKo4qzVe6bOgh4dB_By5w41tVrH0p8mWJleGSO5w-0zJSqdZv4ppLzaRZXILaaEd3MWTNHttmJvN7U2EW-1WR9g_wRBW8WlkcXByPIkEpriD0fR_1MWkYwyA7w8fG1NUIpa8UBzy1G48viWako7kEF/s1042/Screenshot%202024-02-28%20120616.png)
#
# 3. Loyalty Table
#
# ![3](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEjyZzVWEKdubh4LHQRmkoOnQS9mso515aYfuOGgO-PGngm_Z9DUb8tafEAveHGaSi5uCxDiuBsWSpDTd5zzT_ZgNy4TegVcDB2pIN0vZKlQsRvFE4I94Boh3YpkkuxyZCD8kTz9ECXuwKqeNa_GZ48kh1AvCaZ6Ec57aCvtMjIlOzzaH8HH7EmA-MpQDWke/s1016/24W10%20Loyalty.png)
#
# ### Requirements
#
# - Input the data
# - Filter to the last 2 years of data i.e. only 2023 and 2024 transactions
# - This will allow for year on year comparison
# - Create additional rows of data for the days the store was closed, ensuring all other fields will have null values
# - The store is closed on Sundays and Public Holidays
# - Update the Cash_or_Card field so that:
# - 1=Card
# - 2=Cash
# - Join the Product Table
# - You'll need to prepare the join clause fields first
# - Calculate the Quantity of each transaction
# - Defined as the Sales_Before_Discount / Selling_Price
# - In the Loyalty Table:
# - The Customer_Name is currently reading Last Name, First Name. Update it to read First Name Last Name in Title case
# - e.g. knell, libby becomes Libby Knell
# - Group together the Loyalty_Tiers into Gold, Silver and Bronze
# - Update the Loyalty_Discount to be a numeric field
# - Join the Loyalty Table
# - Create a Sales_After_Discount field to apply the Loyalty_Discount for transactions with a Loyalty_Number
# - Calculate the Profit, defined as:
# - Sales_After_Discount - (Unit_Cost * Quantity)
# - Update the field names to remove all underscores and replace them with spaces
# - Remove any unnecessary fields
# - Output the data
# - If you're working in a tool that allows you to create a Published Data Source, that would be best, as we're preparing the data for Pulse!
#
# ### Output
#
# ![4](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEi_VI39Xs1bHMGkPODGH1xQV6vwasEb9g7k-J-CUg53tTBA2IFcJFqCej3K8vPR0xUjsQSr9AyAeAYMp0PgLdp79wQuL2j8kyJ-RnF4D2PLvHvFdkip0W0y3wKw5L_Chf4zMw4T8QKgZyj6sv35Pr28lyb0N6UuqJSlO9KouueNgvkomZEsdLAumvE6k1Ls/s1274/Screenshot%202024-02-28%20120907.png)
#
# - 14 fields
# - Transaction Date
# - Transaction Number
# - Product Type
# - Product Scent
# - Product Size
# - Cash or Card
# - Loyalty Number
# - Customer Name
# - Loyalty Tier
# - Loyalty Discount
# - Quantity
# - Sales Before Discount
# - Sales After Discount
# - Profit
# - 39,337 rows (39,338 including headers)

# %%
import pandas as pd

# Read the Excel file
excel_file = '2024W10 Input.xlsx'

# List all sheet names
sheet_names = pd.ExcelFile(excel_file).sheet_names
print(sheet_names)
# Out:
# ['Product Table', 'Transaction Data', 'Loyalty Table']

# %%
product_df = pd.read_excel(excel_file, sheet_name=sheet_names[0])


product_df
# Out:
#    Product_Type     Product_Scent Pack_Size Product_Size  Unit_Cost  \
# 0           Bar   Lavender Fields        1x          NaN       1.25
# 1           Bar     Citrus Breeze        1x          NaN       0.75
# 2           Bar        Ocean Mist        1x          NaN       0.66
# 3           Bar        Fresh Rain        1x          NaN       0.94
# 4           Bar       Rose Garden        1x          NaN       1.55
# 5           Bar   Eucalyptus Mint        1x          NaN       1.89
# 6           Bar  Sandalwood Spice        1x          NaN       2.04
# 7           Bar      Vanilla Bean        1x          NaN       2.50
# 8           Bar     Coconut Dream        1x          NaN       1.44
# 9           Bar  Cedarwood Forest        1x          NaN       1.11
# 10          Bar   Lavender Fields        2x          NaN       2.38
# 11          Bar     Citrus Breeze        2x          NaN       1.42
# 12          Bar        Ocean Mist        2x          NaN       1.25
# 13          Bar        Fresh Rain        2x          NaN       1.79
# 14          Bar       Rose Garden        2x          NaN       2.95
# 15          Bar   Eucalyptus Mint        2x          NaN       3.59
# 16          Bar  Sandalwood Spice        2x          NaN       3.88
# 17          Bar      Vanilla Bean        2x          NaN       4.75
# 18          Bar     Coconut Dream        2x          NaN       2.74
# 19          Bar  Cedarwood Forest        2x          NaN       2.11
# 20          Bar   Lavender Fields        4x          NaN       4.50
# 21          Bar     Citrus Breeze        4x          NaN       2.70
# 22          Bar        Ocean Mist        4x          NaN       2.38
# 23          Bar        Fresh Rain        4x          NaN       3.38
# 24          Bar       Rose Garden        4x          NaN       5.58
# 25          Bar   Eucalyptus Mint        4x          NaN       6.80
# 26          Bar  Sandalwood Spice        4x          NaN       7.34
# 27          Bar      Vanilla Bean        4x          NaN       9.00
# 28          Bar     Coconut Dream        4x          NaN       5.18
# 29          Bar  Cedarwood Forest        4x          NaN       4.00
# 30       Liquid   Lavender Fields       NaN        0.25L       1.50
# 31       Liquid     Citrus Breeze       NaN        0.25L       0.90
# 32       Liquid        Ocean Mist       NaN        0.25L       0.79
# 33       Liquid        Fresh Rain       NaN        0.25L       1.13
# 34       Liquid       Rose Garden       NaN        0.25L       1.86
# 35       Liquid   Eucalyptus Mint       NaN        0.25L       2.27
# 36       Liquid  Sandalwood Spice       NaN        0.25L       2.45
# 37       Liquid      Vanilla Bean       NaN        0.25L       3.00
# 38       Liquid     Coconut Dream       NaN        0.25L       1.73
# 39       Liquid  Cedarwood Forest       NaN        0.25L       1.33
# 40       Liquid   Lavender Fields       NaN         0.5L       2.99
# 41       Liquid     Citrus Breeze       NaN         0.5L       1.79
# 42       Liquid        Ocean Mist       NaN         0.5L       1.58
# 43       Liquid        Fresh Rain       NaN         0.5L       2.24
# 44       Liquid       Rose Garden       NaN         0.5L       3.70
# 45       Liquid   Eucalyptus Mint       NaN         0.5L       4.51
# 46       Liquid  Sandalwood Spice       NaN         0.5L       4.87
# 47       Liquid      Vanilla Bean       NaN         0.5L       5.97
# 48       Liquid     Coconut Dream       NaN         0.5L       3.44
# 49       Liquid  Cedarwood Forest       NaN         0.5L       2.65
# 50       Liquid   Lavender Fields       NaN           1L       5.93
# 51       Liquid     Citrus Breeze       NaN           1L       3.55
# 52       Liquid        Ocean Mist       NaN           1L       3.13
# 53       Liquid        Fresh Rain       NaN           1L       4.46
# 54       Liquid       Rose Garden       NaN           1L       7.35
# 55       Liquid   Eucalyptus Mint       NaN           1L       8.96
# 56       Liquid  Sandalwood Spice       NaN           1L       9.67
# 57       Liquid      Vanilla Bean       NaN           1L      11.85
# 58       Liquid     Coconut Dream       NaN           1L       6.83
# 59       Liquid  Cedarwood Forest       NaN           1L       5.26
#
#     Selling_Price
# 0            1.77
# 1            0.81
# 2            1.20
# 3            1.61
# 4            2.45
# 5            3.49
# 6            3.75
# 7            3.64
# 8            2.74
# 9            2.18
# 10           2.41
# 11           2.02
# 12           2.04
# 13           1.89
# 14           3.17
# 15           6.23
# 16           7.57
# 17           6.86
# 18           4.32
# 19           3.05
# 20           5.10
# 21           4.06
# 22           4.65
# 23           4.28
# 24           8.37
# 25           8.30
# 26           7.99
# 27          17.74
# 28           9.63
# 29           5.30
# 30           2.30
# 31           1.46
# 32           1.55
# 33           1.43
# 34           1.90
# 35           4.50
# 36           4.25
# 37           4.61
# 38           2.38
# 39           1.56
# 40           4.95
# 41           2.48
# 42           2.91
# 43           2.25
# 44           7.05
# 45           8.88
# 46           9.56
# 47           7.35
# 48           4.12
# 49           4.39
# 50           8.09
# 51           5.92
# 52           4.59
# 53           8.15
# 54          11.85
# 55          13.27
# 56          13.19
# 57          12.50
# 58           7.50
# 59           6.76

# %%
trans_data_df = pd.read_excel(excel_file, sheet_name=sheet_names[1])
trans_data_df
# Out:
#              Transaction_Date  Transanction_Number  \
# 0       Sat, January 02, 2021             20121001
# 1       Sat, January 02, 2021             20121001
# 2       Sat, January 02, 2021             20121002
# 3       Sat, January 02, 2021             20121002
# 4       Sat, January 02, 2021             20121003
# ...                       ...                  ...
# 105490    Wed, March 06, 2024             60324062
# 105491    Wed, March 06, 2024             60324062
# 105492    Wed, March 06, 2024             60324063
# 105493    Wed, March 06, 2024             60324063
# 105494    Wed, March 06, 2024             60324064
#
#                            Product_ID  Cash_or_Card  Loyalty_Number  \
# 0                   Bar-Ocean_Mist-1x             1       1004721.0
# 1             Liquid-Rose_Garden-0.5L             1       1004721.0
# 2                Bar-Citrus_Breeze-4x             2       1009280.0
# 3           Liquid-Coconut_Dream-0.5L             2       1009280.0
# 4                   Bar-Ocean_Mist-4x             1       1009022.0
# ...                               ...           ...             ...
# 105490        Bar-Sandalwood_Spice-4x             2       1001139.0
# 105491  Liquid-Cedarwood_Forest-0.25L             2       1001139.0
# 105492      Liquid-Citrus_Breeze-0.5L             1       1007693.0
# 105493   Liquid-Sandalwood_Spice-0.5L             1       1007693.0
# 105494              Bar-Fresh_Rain-4x             1       1007047.0
#
#         Sales_Before_Discount
# 0                        6.00
# 1                       14.10
# 2                        8.12
# 3                       12.36
# 4                       13.95
# ...                       ...
# 105490                  31.96
# 105491                   7.80
# 105492                   2.48
# 105493                  47.80
# 105494                  21.40
#
# [105495 rows x 6 columns]

# %%
loyalty_df = pd.read_excel(excel_file, sheet_name=sheet_names[2])
loyalty_df
# Out:
#       Loyalty_Number         Customer_Name Loyalty_Tier Loyalty_Discount
# 0            1000012     trimmill, leeanne        Bronz              NaN
# 1            1000026     kobierski, teador          NaN              NaN
# 2            1000028        plues, jenelle        Bronz              NaN
# 3            1000032    firmager, gabriell        Bronz              NaN
# 4            1000038       chiles, nicolea          NaN              NaN
# ...              ...                   ...          ...              ...
# 9784         1009987  rattenberie, thacher       Sliver              10%
# 9785         1009990      mariaud, rosanna       Sliver              10%
# 9786         1009991     d'ambrogio, edgar       Silver              10%
# 9787         1009995       scrivener, mark       Silver              10%
# 9788         1010000          fisk, mendie       Sliver              10%
#
# [9789 rows x 4 columns]

# %%
# Convert Transaction_Date to datetime format
trans_data_df['Transaction_Date'] = pd.to_datetime(trans_data_df['Transaction_Date'])

# Filter to the last 2 years of data (2023 and 2024)
filtered_trans_data_df = trans_data_df[(trans_data_df['Transaction_Date'].dt.year >= 2023) & (trans_data_df['Transaction_Date'].dt.year <= 2024)]

filtered_trans_data_df
# Out:
#        Transaction_Date  Transanction_Number                     Product_ID  \
# 66228        2023-01-03             30123001  Liquid-Sandalwood_Spice-0.25L
# 66229        2023-01-03             30123001       Liquid-Vanilla_Bean-0.5L
# 66230        2023-01-03             30123002     Liquid-Sandalwood_Spice-1L
# 66231        2023-01-03             30123003   Liquid-Eucalyptus_Mint-0.25L
# 66232        2023-01-03             30123003      Liquid-Eucalyptus_Mint-1L
# ...                 ...                  ...                            ...
# 105490       2024-03-06             60324062        Bar-Sandalwood_Spice-4x
# 105491       2024-03-06             60324062  Liquid-Cedarwood_Forest-0.25L
# 105492       2024-03-06             60324063      Liquid-Citrus_Breeze-0.5L
# 105493       2024-03-06             60324063   Liquid-Sandalwood_Spice-0.5L
# 105494       2024-03-06             60324064              Bar-Fresh_Rain-4x
#
#         Cash_or_Card  Loyalty_Number  Sales_Before_Discount
# 66228              2       1005245.0                   8.50
# 66229              2       1005245.0                  14.70
# 66230              1       1007270.0                  13.19
# 66231              2       1009750.0                   9.00
# 66232              2       1009750.0                  39.81
# ...              ...             ...                    ...
# 105490             2       1001139.0                  31.96
# 105491             2       1001139.0                   7.80
# 105492             1       1007693.0                   2.48
# 105493             1       1007693.0                  47.80
# 105494             1       1007047.0                  21.40
#
# [39267 rows x 6 columns]

# %%
# Define the complete date range from the minimum to the maximum date in the filtered transaction data
complete_date_range = pd.date_range(start=filtered_trans_data_df['Transaction_Date'].min(), 
									end=filtered_trans_data_df['Transaction_Date'].max(), 
									freq='D')

# Create a DataFrame with all dates in the range
all_dates_df = pd.DataFrame({'Transaction_Date': complete_date_range})

# Merge with the filtered transaction data to find missing dates
extended_trans_data_df = all_dates_df.merge(filtered_trans_data_df, on='Transaction_Date', how='left')

extended_trans_data_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount
# 0               2.0       1005245.0                   8.50
# 1               2.0       1005245.0                  14.70
# 2               1.0       1007270.0                  13.19
# 3               2.0       1009750.0                   9.00
# 4               2.0       1009750.0                  39.81
# ...             ...             ...                    ...
# 39332           2.0       1001139.0                  31.96
# 39333           2.0       1001139.0                   7.80
# 39334           1.0       1007693.0                   2.48
# 39335           1.0       1007693.0                  47.80
# 39336           1.0       1007047.0                  21.40
#
# [39337 rows x 6 columns]

# %%
# Replace values in the 'Cash_or_Card' column
filtered_trans_data_df['Cash_or_Card'] = filtered_trans_data_df['Cash_or_Card'].replace({1: 'Card', 2: 'Cash'})
extended_trans_data_df
# Out:
# C:\Users\Raguna\AppData\Local\Temp\ipykernel_27024\791140209.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_trans_data_df['Cash_or_Card'] = filtered_trans_data_df['Cash_or_Card'].replace({1: 'Card', 2: 'Cash'})
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount
# 0               2.0       1005245.0                   8.50
# 1               2.0       1005245.0                  14.70
# 2               1.0       1007270.0                  13.19
# 3               2.0       1009750.0                   9.00
# 4               2.0       1009750.0                  39.81
# ...             ...             ...                    ...
# 39332           2.0       1001139.0                  31.96
# 39333           2.0       1001139.0                   7.80
# 39334           1.0       1007693.0                   2.48
# 39335           1.0       1007693.0                  47.80
# 39336           1.0       1007047.0                  21.40
#
# [39337 rows x 6 columns]

# %%
# Merge Pack_Size and Product_Size into a new column called 'Size'
product_df['Size'] = product_df['Pack_Size'].fillna('') + product_df['Product_Size'].fillna('')

# Drop the original Pack_Size and Product_Size columns
product_df = product_df.drop(columns=['Pack_Size', 'Product_Size'])

product_df
# Out:
#    Product_Type     Product_Scent  Unit_Cost  Selling_Price   Size
# 0           Bar   Lavender Fields       1.25           1.77     1x
# 1           Bar     Citrus Breeze       0.75           0.81     1x
# 2           Bar        Ocean Mist       0.66           1.20     1x
# 3           Bar        Fresh Rain       0.94           1.61     1x
# 4           Bar       Rose Garden       1.55           2.45     1x
# 5           Bar   Eucalyptus Mint       1.89           3.49     1x
# 6           Bar  Sandalwood Spice       2.04           3.75     1x
# 7           Bar      Vanilla Bean       2.50           3.64     1x
# 8           Bar     Coconut Dream       1.44           2.74     1x
# 9           Bar  Cedarwood Forest       1.11           2.18     1x
# 10          Bar   Lavender Fields       2.38           2.41     2x
# 11          Bar     Citrus Breeze       1.42           2.02     2x
# 12          Bar        Ocean Mist       1.25           2.04     2x
# 13          Bar        Fresh Rain       1.79           1.89     2x
# 14          Bar       Rose Garden       2.95           3.17     2x
# 15          Bar   Eucalyptus Mint       3.59           6.23     2x
# 16          Bar  Sandalwood Spice       3.88           7.57     2x
# 17          Bar      Vanilla Bean       4.75           6.86     2x
# 18          Bar     Coconut Dream       2.74           4.32     2x
# 19          Bar  Cedarwood Forest       2.11           3.05     2x
# 20          Bar   Lavender Fields       4.50           5.10     4x
# 21          Bar     Citrus Breeze       2.70           4.06     4x
# 22          Bar        Ocean Mist       2.38           4.65     4x
# 23          Bar        Fresh Rain       3.38           4.28     4x
# 24          Bar       Rose Garden       5.58           8.37     4x
# 25          Bar   Eucalyptus Mint       6.80           8.30     4x
# 26          Bar  Sandalwood Spice       7.34           7.99     4x
# 27          Bar      Vanilla Bean       9.00          17.74     4x
# 28          Bar     Coconut Dream       5.18           9.63     4x
# 29          Bar  Cedarwood Forest       4.00           5.30     4x
# 30       Liquid   Lavender Fields       1.50           2.30  0.25L
# 31       Liquid     Citrus Breeze       0.90           1.46  0.25L
# 32       Liquid        Ocean Mist       0.79           1.55  0.25L
# 33       Liquid        Fresh Rain       1.13           1.43  0.25L
# 34       Liquid       Rose Garden       1.86           1.90  0.25L
# 35       Liquid   Eucalyptus Mint       2.27           4.50  0.25L
# 36       Liquid  Sandalwood Spice       2.45           4.25  0.25L
# 37       Liquid      Vanilla Bean       3.00           4.61  0.25L
# 38       Liquid     Coconut Dream       1.73           2.38  0.25L
# 39       Liquid  Cedarwood Forest       1.33           1.56  0.25L
# 40       Liquid   Lavender Fields       2.99           4.95   0.5L
# 41       Liquid     Citrus Breeze       1.79           2.48   0.5L
# 42       Liquid        Ocean Mist       1.58           2.91   0.5L
# 43       Liquid        Fresh Rain       2.24           2.25   0.5L
# 44       Liquid       Rose Garden       3.70           7.05   0.5L
# 45       Liquid   Eucalyptus Mint       4.51           8.88   0.5L
# 46       Liquid  Sandalwood Spice       4.87           9.56   0.5L
# 47       Liquid      Vanilla Bean       5.97           7.35   0.5L
# 48       Liquid     Coconut Dream       3.44           4.12   0.5L
# 49       Liquid  Cedarwood Forest       2.65           4.39   0.5L
# 50       Liquid   Lavender Fields       5.93           8.09     1L
# 51       Liquid     Citrus Breeze       3.55           5.92     1L
# 52       Liquid        Ocean Mist       3.13           4.59     1L
# 53       Liquid        Fresh Rain       4.46           8.15     1L
# 54       Liquid       Rose Garden       7.35          11.85     1L
# 55       Liquid   Eucalyptus Mint       8.96          13.27     1L
# 56       Liquid  Sandalwood Spice       9.67          13.19     1L
# 57       Liquid      Vanilla Bean      11.85          12.50     1L
# 58       Liquid     Coconut Dream       6.83           7.50     1L
# 59       Liquid  Cedarwood Forest       5.26           6.76     1L

# %%
# Replace spaces with underscores in the Product_Scent column
product_df['Product_Scent'] = product_df['Product_Scent'].str.replace(' ', '_')
product_df
# Out:
#    Product_Type     Product_Scent  Unit_Cost  Selling_Price   Size
# 0           Bar   Lavender_Fields       1.25           1.77     1x
# 1           Bar     Citrus_Breeze       0.75           0.81     1x
# 2           Bar        Ocean_Mist       0.66           1.20     1x
# 3           Bar        Fresh_Rain       0.94           1.61     1x
# 4           Bar       Rose_Garden       1.55           2.45     1x
# 5           Bar   Eucalyptus_Mint       1.89           3.49     1x
# 6           Bar  Sandalwood_Spice       2.04           3.75     1x
# 7           Bar      Vanilla_Bean       2.50           3.64     1x
# 8           Bar     Coconut_Dream       1.44           2.74     1x
# 9           Bar  Cedarwood_Forest       1.11           2.18     1x
# 10          Bar   Lavender_Fields       2.38           2.41     2x
# 11          Bar     Citrus_Breeze       1.42           2.02     2x
# 12          Bar        Ocean_Mist       1.25           2.04     2x
# 13          Bar        Fresh_Rain       1.79           1.89     2x
# 14          Bar       Rose_Garden       2.95           3.17     2x
# 15          Bar   Eucalyptus_Mint       3.59           6.23     2x
# 16          Bar  Sandalwood_Spice       3.88           7.57     2x
# 17          Bar      Vanilla_Bean       4.75           6.86     2x
# 18          Bar     Coconut_Dream       2.74           4.32     2x
# 19          Bar  Cedarwood_Forest       2.11           3.05     2x
# 20          Bar   Lavender_Fields       4.50           5.10     4x
# 21          Bar     Citrus_Breeze       2.70           4.06     4x
# 22          Bar        Ocean_Mist       2.38           4.65     4x
# 23          Bar        Fresh_Rain       3.38           4.28     4x
# 24          Bar       Rose_Garden       5.58           8.37     4x
# 25          Bar   Eucalyptus_Mint       6.80           8.30     4x
# 26          Bar  Sandalwood_Spice       7.34           7.99     4x
# 27          Bar      Vanilla_Bean       9.00          17.74     4x
# 28          Bar     Coconut_Dream       5.18           9.63     4x
# 29          Bar  Cedarwood_Forest       4.00           5.30     4x
# 30       Liquid   Lavender_Fields       1.50           2.30  0.25L
# 31       Liquid     Citrus_Breeze       0.90           1.46  0.25L
# 32       Liquid        Ocean_Mist       0.79           1.55  0.25L
# 33       Liquid        Fresh_Rain       1.13           1.43  0.25L
# 34       Liquid       Rose_Garden       1.86           1.90  0.25L
# 35       Liquid   Eucalyptus_Mint       2.27           4.50  0.25L
# 36       Liquid  Sandalwood_Spice       2.45           4.25  0.25L
# 37       Liquid      Vanilla_Bean       3.00           4.61  0.25L
# 38       Liquid     Coconut_Dream       1.73           2.38  0.25L
# 39       Liquid  Cedarwood_Forest       1.33           1.56  0.25L
# 40       Liquid   Lavender_Fields       2.99           4.95   0.5L
# 41       Liquid     Citrus_Breeze       1.79           2.48   0.5L
# 42       Liquid        Ocean_Mist       1.58           2.91   0.5L
# 43       Liquid        Fresh_Rain       2.24           2.25   0.5L
# 44       Liquid       Rose_Garden       3.70           7.05   0.5L
# 45       Liquid   Eucalyptus_Mint       4.51           8.88   0.5L
# 46       Liquid  Sandalwood_Spice       4.87           9.56   0.5L
# 47       Liquid      Vanilla_Bean       5.97           7.35   0.5L
# 48       Liquid     Coconut_Dream       3.44           4.12   0.5L
# 49       Liquid  Cedarwood_Forest       2.65           4.39   0.5L
# 50       Liquid   Lavender_Fields       5.93           8.09     1L
# 51       Liquid     Citrus_Breeze       3.55           5.92     1L
# 52       Liquid        Ocean_Mist       3.13           4.59     1L
# 53       Liquid        Fresh_Rain       4.46           8.15     1L
# 54       Liquid       Rose_Garden       7.35          11.85     1L
# 55       Liquid   Eucalyptus_Mint       8.96          13.27     1L
# 56       Liquid  Sandalwood_Spice       9.67          13.19     1L
# 57       Liquid      Vanilla_Bean      11.85          12.50     1L
# 58       Liquid     Coconut_Dream       6.83           7.50     1L
# 59       Liquid  Cedarwood_Forest       5.26           6.76     1L

# %%
# Create merge key
product_df['merge_key'] = product_df['Product_Type'] + '-' + product_df['Product_Scent'] + '-' + product_df['Size']
product_df
# Out:
#    Product_Type     Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0           Bar   Lavender_Fields       1.25           1.77     1x
# 1           Bar     Citrus_Breeze       0.75           0.81     1x
# 2           Bar        Ocean_Mist       0.66           1.20     1x
# 3           Bar        Fresh_Rain       0.94           1.61     1x
# 4           Bar       Rose_Garden       1.55           2.45     1x
# 5           Bar   Eucalyptus_Mint       1.89           3.49     1x
# 6           Bar  Sandalwood_Spice       2.04           3.75     1x
# 7           Bar      Vanilla_Bean       2.50           3.64     1x
# 8           Bar     Coconut_Dream       1.44           2.74     1x
# 9           Bar  Cedarwood_Forest       1.11           2.18     1x
# 10          Bar   Lavender_Fields       2.38           2.41     2x
# 11          Bar     Citrus_Breeze       1.42           2.02     2x
# 12          Bar        Ocean_Mist       1.25           2.04     2x
# 13          Bar        Fresh_Rain       1.79           1.89     2x
# 14          Bar       Rose_Garden       2.95           3.17     2x
# 15          Bar   Eucalyptus_Mint       3.59           6.23     2x
# 16          Bar  Sandalwood_Spice       3.88           7.57     2x
# 17          Bar      Vanilla_Bean       4.75           6.86     2x
# 18          Bar     Coconut_Dream       2.74           4.32     2x
# 19          Bar  Cedarwood_Forest       2.11           3.05     2x
# 20          Bar   Lavender_Fields       4.50           5.10     4x
# 21          Bar     Citrus_Breeze       2.70           4.06     4x
# 22          Bar        Ocean_Mist       2.38           4.65     4x
# 23          Bar        Fresh_Rain       3.38           4.28     4x
# 24          Bar       Rose_Garden       5.58           8.37     4x
# 25          Bar   Eucalyptus_Mint       6.80           8.30     4x
# 26          Bar  Sandalwood_Spice       7.34           7.99     4x
# 27          Bar      Vanilla_Bean       9.00          17.74     4x
# 28          Bar     Coconut_Dream       5.18           9.63     4x
# 29          Bar  Cedarwood_Forest       4.00           5.30     4x
# 30       Liquid   Lavender_Fields       1.50           2.30  0.25L
# 31       Liquid     Citrus_Breeze       0.90           1.46  0.25L
# 32       Liquid        Ocean_Mist       0.79           1.55  0.25L
# 33       Liquid        Fresh_Rain       1.13           1.43  0.25L
# 34       Liquid       Rose_Garden       1.86           1.90  0.25L
# 35       Liquid   Eucalyptus_Mint       2.27           4.50  0.25L
# 36       Liquid  Sandalwood_Spice       2.45           4.25  0.25L
# 37       Liquid      Vanilla_Bean       3.00           4.61  0.25L
# 38       Liquid     Coconut_Dream       1.73           2.38  0.25L
# 39       Liquid  Cedarwood_Forest       1.33           1.56  0.25L
# 40       Liquid   Lavender_Fields       2.99           4.95   0.5L
# 41       Liquid     Citrus_Breeze       1.79           2.48   0.5L
# 42       Liquid        Ocean_Mist       1.58           2.91   0.5L
# 43       Liquid        Fresh_Rain       2.24           2.25   0.5L
# 44       Liquid       Rose_Garden       3.70           7.05   0.5L
# 45       Liquid   Eucalyptus_Mint       4.51           8.88   0.5L
# 46       Liquid  Sandalwood_Spice       4.87           9.56   0.5L
# 47       Liquid      Vanilla_Bean       5.97           7.35   0.5L
# 48       Liquid     Coconut_Dream       3.44           4.12   0.5L
# 49       Liquid  Cedarwood_Forest       2.65           4.39   0.5L
# 50       Liquid   Lavender_Fields       5.93           8.09     1L
# 51       Liquid     Citrus_Breeze       3.55           5.92     1L
# 52       Liquid        Ocean_Mist       3.13           4.59     1L
# 53       Liquid        Fresh_Rain       4.46           8.15     1L
# 54       Liquid       Rose_Garden       7.35          11.85     1L
# 55       Liquid   Eucalyptus_Mint       8.96          13.27     1L
# 56       Liquid  Sandalwood_Spice       9.67          13.19     1L
# 57       Liquid      Vanilla_Bean      11.85          12.50     1L
# 58       Liquid     Coconut_Dream       6.83           7.50     1L
# 59       Liquid  Cedarwood_Forest       5.26           6.76     1L
#
#                         merge_key
# 0          Bar-Lavender_Fields-1x
# 1            Bar-Citrus_Breeze-1x
# 2               Bar-Ocean_Mist-1x
# 3               Bar-Fresh_Rain-1x
# 4              Bar-Rose_Garden-1x
# 5          Bar-Eucalyptus_Mint-1x
# 6         Bar-Sandalwood_Spice-1x
# 7             Bar-Vanilla_Bean-1x
# 8            Bar-Coconut_Dream-1x
# 9         Bar-Cedarwood_Forest-1x
# 10         Bar-Lavender_Fields-2x
# 11           Bar-Citrus_Breeze-2x
# 12              Bar-Ocean_Mist-2x
# 13              Bar-Fresh_Rain-2x
# 14             Bar-Rose_Garden-2x
# 15         Bar-Eucalyptus_Mint-2x
# 16        Bar-Sandalwood_Spice-2x
# 17            Bar-Vanilla_Bean-2x
# 18           Bar-Coconut_Dream-2x
# 19        Bar-Cedarwood_Forest-2x
# 20         Bar-Lavender_Fields-4x
# 21           Bar-Citrus_Breeze-4x
# 22              Bar-Ocean_Mist-4x
# 23              Bar-Fresh_Rain-4x
# 24             Bar-Rose_Garden-4x
# 25         Bar-Eucalyptus_Mint-4x
# 26        Bar-Sandalwood_Spice-4x
# 27            Bar-Vanilla_Bean-4x
# 28           Bar-Coconut_Dream-4x
# 29        Bar-Cedarwood_Forest-4x
# 30   Liquid-Lavender_Fields-0.25L
# 31     Liquid-Citrus_Breeze-0.25L
# 32        Liquid-Ocean_Mist-0.25L
# 33        Liquid-Fresh_Rain-0.25L
# 34       Liquid-Rose_Garden-0.25L
# 35   Liquid-Eucalyptus_Mint-0.25L
# 36  Liquid-Sandalwood_Spice-0.25L
# 37      Liquid-Vanilla_Bean-0.25L
# 38     Liquid-Coconut_Dream-0.25L
# 39  Liquid-Cedarwood_Forest-0.25L
# 40    Liquid-Lavender_Fields-0.5L
# 41      Liquid-Citrus_Breeze-0.5L
# 42         Liquid-Ocean_Mist-0.5L
# 43         Liquid-Fresh_Rain-0.5L
# 44        Liquid-Rose_Garden-0.5L
# 45    Liquid-Eucalyptus_Mint-0.5L
# 46   Liquid-Sandalwood_Spice-0.5L
# 47       Liquid-Vanilla_Bean-0.5L
# 48      Liquid-Coconut_Dream-0.5L
# 49   Liquid-Cedarwood_Forest-0.5L
# 50      Liquid-Lavender_Fields-1L
# 51        Liquid-Citrus_Breeze-1L
# 52           Liquid-Ocean_Mist-1L
# 53           Liquid-Fresh_Rain-1L
# 54          Liquid-Rose_Garden-1L
# 55      Liquid-Eucalyptus_Mint-1L
# 56     Liquid-Sandalwood_Spice-1L
# 57         Liquid-Vanilla_Bean-1L
# 58        Liquid-Coconut_Dream-1L
# 59     Liquid-Cedarwood_Forest-1L

# %%
# Perform a left join
merged_df = extended_trans_data_df.merge(product_df, how='left', left_on='Product_ID', right_on='merge_key')

merged_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount Product_Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge_key
# 0      Liquid-Sandalwood_Spice-0.25L
# 1           Liquid-Vanilla_Bean-0.5L
# 2         Liquid-Sandalwood_Spice-1L
# 3       Liquid-Eucalyptus_Mint-0.25L
# 4          Liquid-Eucalyptus_Mint-1L
# ...                              ...
# 39332        Bar-Sandalwood_Spice-4x
# 39333  Liquid-Cedarwood_Forest-0.25L
# 39334      Liquid-Citrus_Breeze-0.5L
# 39335   Liquid-Sandalwood_Spice-0.5L
# 39336              Bar-Fresh_Rain-4x
#
# [39337 rows x 12 columns]

# %%
# calculate quantity
merged_df['Quantity'] = merged_df['Sales_Before_Discount'] / merged_df['Selling_Price']
merged_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount Product_Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge_key  Quantity
# 0      Liquid-Sandalwood_Spice-0.25L       2.0
# 1           Liquid-Vanilla_Bean-0.5L       2.0
# 2         Liquid-Sandalwood_Spice-1L       1.0
# 3       Liquid-Eucalyptus_Mint-0.25L       2.0
# 4          Liquid-Eucalyptus_Mint-1L       3.0
# ...                              ...       ...
# 39332        Bar-Sandalwood_Spice-4x       4.0
# 39333  Liquid-Cedarwood_Forest-0.25L       5.0
# 39334      Liquid-Citrus_Breeze-0.5L       1.0
# 39335   Liquid-Sandalwood_Spice-0.5L       5.0
# 39336              Bar-Fresh_Rain-4x       5.0
#
# [39337 rows x 13 columns]

# %%
# Split the Customer_Name into Last Name and First Name, then swap and convert to title case
loyalty_df['Customer_Name'] = loyalty_df['Customer_Name'].apply(lambda x: ' '.join(reversed(x.split(', '))).title())

loyalty_df
# Out:
#       Loyalty_Number        Customer_Name Loyalty_Tier Loyalty_Discount
# 0            1000012     Leeanne Trimmill        Bronz              NaN
# 1            1000026     Teador Kobierski          NaN              NaN
# 2            1000028        Jenelle Plues        Bronz              NaN
# 3            1000032    Gabriell Firmager        Bronz              NaN
# 4            1000038       Nicolea Chiles          NaN              NaN
# ...              ...                  ...          ...              ...
# 9784         1009987  Thacher Rattenberie       Sliver              10%
# 9785         1009990      Rosanna Mariaud       Sliver              10%
# 9786         1009991     Edgar D'Ambrogio       Silver              10%
# 9787         1009995       Mark Scrivener       Silver              10%
# 9788         1010000          Mendie Fisk       Sliver              10%
#
# [9789 rows x 4 columns]

# %%
# list unique loyalty tiers
unique_loyalty_tiers = loyalty_df['Loyalty_Tier'].unique()
print(unique_loyalty_tiers)
# Out:
# ['Bronz' nan 'Bronze' 'bronze' 'Goald' 'Gold' 'gold' 'Silver' 'Sliver'
#  'silver']

# %%
# Define the mapping dictionary
loyalty_tier_mapping = {
    'Bronz': 'Bronze',
    'Bronze': 'Bronze',
    'bronze': 'Bronze',
    'Goald': 'Gold',
    'Gold': 'Gold',
    'gold': 'Gold',
    'Silver': 'Silver',
    'Sliver': 'Silver',
    'silver': 'Silver'
}

# Replace the values in the Loyalty_Tier column
loyalty_df['Loyalty_Tier'] = loyalty_df['Loyalty_Tier'].replace(loyalty_tier_mapping)

loyalty_df
# Out:
#       Loyalty_Number        Customer_Name Loyalty_Tier Loyalty_Discount
# 0            1000012     Leeanne Trimmill       Bronze              NaN
# 1            1000026     Teador Kobierski          NaN              NaN
# 2            1000028        Jenelle Plues       Bronze              NaN
# 3            1000032    Gabriell Firmager       Bronze              NaN
# 4            1000038       Nicolea Chiles          NaN              NaN
# ...              ...                  ...          ...              ...
# 9784         1009987  Thacher Rattenberie       Silver              10%
# 9785         1009990      Rosanna Mariaud       Silver              10%
# 9786         1009991     Edgar D'Ambrogio       Silver              10%
# 9787         1009995       Mark Scrivener       Silver              10%
# 9788         1010000          Mendie Fisk       Silver              10%
#
# [9789 rows x 4 columns]

# %%
# Convert Loyalty_Discount to numeric, removing the '%' sign first
loyalty_df['Loyalty_Discount'] = loyalty_df['Loyalty_Discount'].str.rstrip('%').astype('float') / 100.0

loyalty_df
# Out:
#       Loyalty_Number        Customer_Name Loyalty_Tier  Loyalty_Discount
# 0            1000012     Leeanne Trimmill       Bronze               NaN
# 1            1000026     Teador Kobierski          NaN               NaN
# 2            1000028        Jenelle Plues       Bronze               NaN
# 3            1000032    Gabriell Firmager       Bronze               NaN
# 4            1000038       Nicolea Chiles          NaN               NaN
# ...              ...                  ...          ...               ...
# 9784         1009987  Thacher Rattenberie       Silver               0.1
# 9785         1009990      Rosanna Mariaud       Silver               0.1
# 9786         1009991     Edgar D'Ambrogio       Silver               0.1
# 9787         1009995       Mark Scrivener       Silver               0.1
# 9788         1010000          Mendie Fisk       Silver               0.1
#
# [9789 rows x 4 columns]

# %%
# Perform a left join
final_df = merged_df.merge(loyalty_df, how='left', on='Loyalty_Number')

final_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount Product_Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge_key  Quantity    Customer_Name Loyalty_Tier  \
# 0      Liquid-Sandalwood_Spice-0.25L       2.0  Laurens Squibbs       Bronze
# 1           Liquid-Vanilla_Bean-0.5L       2.0  Laurens Squibbs       Bronze
# 2         Liquid-Sandalwood_Spice-1L       1.0     Cary Breckon       Bronze
# 3       Liquid-Eucalyptus_Mint-0.25L       2.0      Orv Drewitt       Bronze
# 4          Liquid-Eucalyptus_Mint-1L       3.0      Orv Drewitt       Bronze
# ...                              ...       ...              ...          ...
# 39332        Bar-Sandalwood_Spice-4x       4.0     Jae Swindall       Bronze
# 39333  Liquid-Cedarwood_Forest-0.25L       5.0     Jae Swindall       Bronze
# 39334      Liquid-Citrus_Breeze-0.5L       1.0      Rheba Roark       Bronze
# 39335   Liquid-Sandalwood_Spice-0.5L       5.0      Rheba Roark       Bronze
# 39336              Bar-Fresh_Rain-4x       5.0  Sashenka Marchi       Silver
#
#        Loyalty_Discount
# 0                  0.05
# 1                  0.05
# 2                  0.05
# 3                  0.05
# 4                  0.05
# ...                 ...
# 39332              0.05
# 39333              0.05
# 39334              0.05
# 39335              0.05
# 39336              0.10
#
# [39337 rows x 16 columns]

# %%
# Calculate Sales_After_Discount
final_df['Sales_After_Discount'] = final_df.apply(
    lambda row: row['Sales_Before_Discount'] * (1 - row['Loyalty_Discount']) if pd.notnull(row['Loyalty_Number']) else row['Sales_Before_Discount'],
    axis=1
)

final_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount Product_Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge_key  Quantity    Customer_Name Loyalty_Tier  \
# 0      Liquid-Sandalwood_Spice-0.25L       2.0  Laurens Squibbs       Bronze
# 1           Liquid-Vanilla_Bean-0.5L       2.0  Laurens Squibbs       Bronze
# 2         Liquid-Sandalwood_Spice-1L       1.0     Cary Breckon       Bronze
# 3       Liquid-Eucalyptus_Mint-0.25L       2.0      Orv Drewitt       Bronze
# 4          Liquid-Eucalyptus_Mint-1L       3.0      Orv Drewitt       Bronze
# ...                              ...       ...              ...          ...
# 39332        Bar-Sandalwood_Spice-4x       4.0     Jae Swindall       Bronze
# 39333  Liquid-Cedarwood_Forest-0.25L       5.0     Jae Swindall       Bronze
# 39334      Liquid-Citrus_Breeze-0.5L       1.0      Rheba Roark       Bronze
# 39335   Liquid-Sandalwood_Spice-0.5L       5.0      Rheba Roark       Bronze
# 39336              Bar-Fresh_Rain-4x       5.0  Sashenka Marchi       Silver
#
#        Loyalty_Discount  Sales_After_Discount
# 0                  0.05                8.0750
# 1                  0.05               13.9650
# 2                  0.05               12.5305
# 3                  0.05                8.5500
# 4                  0.05               37.8195
# ...                 ...                   ...
# 39332              0.05               30.3620
# 39333              0.05                7.4100
# 39334              0.05                2.3560
# 39335              0.05               45.4100
# 39336              0.10               19.2600
#
# [39337 rows x 17 columns]

# %%
# Calculate Profit
final_df['Profit'] = final_df['Sales_After_Discount'] - (final_df['Unit_Cost'] * final_df['Quantity'])

final_df
# Out:
#       Transaction_Date  Transanction_Number                     Product_ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash_or_Card  Loyalty_Number  Sales_Before_Discount Product_Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product_Scent  Unit_Cost  Selling_Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge_key  Quantity    Customer_Name Loyalty_Tier  \
# 0      Liquid-Sandalwood_Spice-0.25L       2.0  Laurens Squibbs       Bronze
# 1           Liquid-Vanilla_Bean-0.5L       2.0  Laurens Squibbs       Bronze
# 2         Liquid-Sandalwood_Spice-1L       1.0     Cary Breckon       Bronze
# 3       Liquid-Eucalyptus_Mint-0.25L       2.0      Orv Drewitt       Bronze
# 4          Liquid-Eucalyptus_Mint-1L       3.0      Orv Drewitt       Bronze
# ...                              ...       ...              ...          ...
# 39332        Bar-Sandalwood_Spice-4x       4.0     Jae Swindall       Bronze
# 39333  Liquid-Cedarwood_Forest-0.25L       5.0     Jae Swindall       Bronze
# 39334      Liquid-Citrus_Breeze-0.5L       1.0      Rheba Roark       Bronze
# 39335   Liquid-Sandalwood_Spice-0.5L       5.0      Rheba Roark       Bronze
# 39336              Bar-Fresh_Rain-4x       5.0  Sashenka Marchi       Silver
#
#        Loyalty_Discount  Sales_After_Discount   Profit
# 0                  0.05                8.0750   3.1750
# 1                  0.05               13.9650   2.0250
# 2                  0.05               12.5305   2.8605
# 3                  0.05                8.5500   4.0100
# 4                  0.05               37.8195  10.9395
# ...                 ...                   ...      ...
# 39332              0.05               30.3620   1.0020
# 39333              0.05                7.4100   0.7600
# 39334              0.05                2.3560   0.5660
# 39335              0.05               45.4100  21.0600
# 39336              0.10               19.2600   2.3600
#
# [39337 rows x 18 columns]

# %%
# Rename columns
final_df.columns = final_df.columns.str.replace('_', ' ')
final_df
# Out:
#       Transaction Date  Transanction Number                     Product ID  \
# 0           2023-01-03           30123001.0  Liquid-Sandalwood_Spice-0.25L
# 1           2023-01-03           30123001.0       Liquid-Vanilla_Bean-0.5L
# 2           2023-01-03           30123002.0     Liquid-Sandalwood_Spice-1L
# 3           2023-01-03           30123003.0   Liquid-Eucalyptus_Mint-0.25L
# 4           2023-01-03           30123003.0      Liquid-Eucalyptus_Mint-1L
# ...                ...                  ...                            ...
# 39332       2024-03-06           60324062.0        Bar-Sandalwood_Spice-4x
# 39333       2024-03-06           60324062.0  Liquid-Cedarwood_Forest-0.25L
# 39334       2024-03-06           60324063.0      Liquid-Citrus_Breeze-0.5L
# 39335       2024-03-06           60324063.0   Liquid-Sandalwood_Spice-0.5L
# 39336       2024-03-06           60324064.0              Bar-Fresh_Rain-4x
#
#        Cash or Card  Loyalty Number  Sales Before Discount Product Type  \
# 0               2.0       1005245.0                   8.50       Liquid
# 1               2.0       1005245.0                  14.70       Liquid
# 2               1.0       1007270.0                  13.19       Liquid
# 3               2.0       1009750.0                   9.00       Liquid
# 4               2.0       1009750.0                  39.81       Liquid
# ...             ...             ...                    ...          ...
# 39332           2.0       1001139.0                  31.96          Bar
# 39333           2.0       1001139.0                   7.80       Liquid
# 39334           1.0       1007693.0                   2.48       Liquid
# 39335           1.0       1007693.0                  47.80       Liquid
# 39336           1.0       1007047.0                  21.40          Bar
#
#           Product Scent  Unit Cost  Selling Price   Size  \
# 0      Sandalwood_Spice       2.45           4.25  0.25L
# 1          Vanilla_Bean       5.97           7.35   0.5L
# 2      Sandalwood_Spice       9.67          13.19     1L
# 3       Eucalyptus_Mint       2.27           4.50  0.25L
# 4       Eucalyptus_Mint       8.96          13.27     1L
# ...                 ...        ...            ...    ...
# 39332  Sandalwood_Spice       7.34           7.99     4x
# 39333  Cedarwood_Forest       1.33           1.56  0.25L
# 39334     Citrus_Breeze       1.79           2.48   0.5L
# 39335  Sandalwood_Spice       4.87           9.56   0.5L
# 39336        Fresh_Rain       3.38           4.28     4x
#
#                            merge key  Quantity    Customer Name Loyalty Tier  \
# 0      Liquid-Sandalwood_Spice-0.25L       2.0  Laurens Squibbs       Bronze
# 1           Liquid-Vanilla_Bean-0.5L       2.0  Laurens Squibbs       Bronze
# 2         Liquid-Sandalwood_Spice-1L       1.0     Cary Breckon       Bronze
# 3       Liquid-Eucalyptus_Mint-0.25L       2.0      Orv Drewitt       Bronze
# 4          Liquid-Eucalyptus_Mint-1L       3.0      Orv Drewitt       Bronze
# ...                              ...       ...              ...          ...
# 39332        Bar-Sandalwood_Spice-4x       4.0     Jae Swindall       Bronze
# 39333  Liquid-Cedarwood_Forest-0.25L       5.0     Jae Swindall       Bronze
# 39334      Liquid-Citrus_Breeze-0.5L       1.0      Rheba Roark       Bronze
# 39335   Liquid-Sandalwood_Spice-0.5L       5.0      Rheba Roark       Bronze
# 39336              Bar-Fresh_Rain-4x       5.0  Sashenka Marchi       Silver
#
#        Loyalty Discount  Sales After Discount   Profit
# 0                  0.05                8.0750   3.1750
# 1                  0.05               13.9650   2.0250
# 2                  0.05               12.5305   2.8605
# 3                  0.05                8.5500   4.0100
# 4                  0.05               37.8195  10.9395
# ...                 ...                   ...      ...
# 39332              0.05               30.3620   1.0020
# 39333              0.05                7.4100   0.7600
# 39334              0.05                2.3560   0.5660
# 39335              0.05               45.4100  21.0600
# 39336              0.10               19.2600   2.3600
#
# [39337 rows x 18 columns]

# %%
# Remove unnessary columns
final_df = final_df[['Transaction Date', 'Transanction Number', 'Product Type', 'Product Scent', 'Size', 'Cash or Card', 'Loyalty Number', 'Customer Name', 'Loyalty Tier', 'Loyalty Discount', 'Quantity', 'Sales Before Discount', 'Sales After Discount', 'Profit']]
final_df
# Out:
#       Transaction Date  Transanction Number Product Type     Product Scent  \
# 0           2023-01-03           30123001.0       Liquid  Sandalwood_Spice
# 1           2023-01-03           30123001.0       Liquid      Vanilla_Bean
# 2           2023-01-03           30123002.0       Liquid  Sandalwood_Spice
# 3           2023-01-03           30123003.0       Liquid   Eucalyptus_Mint
# 4           2023-01-03           30123003.0       Liquid   Eucalyptus_Mint
# ...                ...                  ...          ...               ...
# 39332       2024-03-06           60324062.0          Bar  Sandalwood_Spice
# 39333       2024-03-06           60324062.0       Liquid  Cedarwood_Forest
# 39334       2024-03-06           60324063.0       Liquid     Citrus_Breeze
# 39335       2024-03-06           60324063.0       Liquid  Sandalwood_Spice
# 39336       2024-03-06           60324064.0          Bar        Fresh_Rain
#
#         Size  Cash or Card  Loyalty Number    Customer Name Loyalty Tier  \
# 0      0.25L           2.0       1005245.0  Laurens Squibbs       Bronze
# 1       0.5L           2.0       1005245.0  Laurens Squibbs       Bronze
# 2         1L           1.0       1007270.0     Cary Breckon       Bronze
# 3      0.25L           2.0       1009750.0      Orv Drewitt       Bronze
# 4         1L           2.0       1009750.0      Orv Drewitt       Bronze
# ...      ...           ...             ...              ...          ...
# 39332     4x           2.0       1001139.0     Jae Swindall       Bronze
# 39333  0.25L           2.0       1001139.0     Jae Swindall       Bronze
# 39334   0.5L           1.0       1007693.0      Rheba Roark       Bronze
# 39335   0.5L           1.0       1007693.0      Rheba Roark       Bronze
# 39336     4x           1.0       1007047.0  Sashenka Marchi       Silver
#
#        Loyalty Discount  Quantity  Sales Before Discount  \
# 0                  0.05       2.0                   8.50
# 1                  0.05       2.0                  14.70
# 2                  0.05       1.0                  13.19
# 3                  0.05       2.0                   9.00
# 4                  0.05       3.0                  39.81
# ...                 ...       ...                    ...
# 39332              0.05       4.0                  31.96
# 39333              0.05       5.0                   7.80
# 39334              0.05       1.0                   2.48
# 39335              0.05       5.0                  47.80
# 39336              0.10       5.0                  21.40
#
#        Sales After Discount   Profit
# 0                    8.0750   3.1750
# 1                   13.9650   2.0250
# 2                   12.5305   2.8605
# 3                    8.5500   4.0100
# 4                   37.8195  10.9395
# ...                     ...      ...
# 39332               30.3620   1.0020
# 39333                7.4100   0.7600
# 39334                2.3560   0.5660
# 39335               45.4100  21.0600
# 39336               19.2600   2.3600
#
# [39337 rows x 14 columns]

# %%
output = final_df
output
# Out:
#       Transaction Date  Transanction Number Product Type     Product Scent  \
# 0           2023-01-03           30123001.0       Liquid  Sandalwood_Spice
# 1           2023-01-03           30123001.0       Liquid      Vanilla_Bean
# 2           2023-01-03           30123002.0       Liquid  Sandalwood_Spice
# 3           2023-01-03           30123003.0       Liquid   Eucalyptus_Mint
# 4           2023-01-03           30123003.0       Liquid   Eucalyptus_Mint
# ...                ...                  ...          ...               ...
# 39332       2024-03-06           60324062.0          Bar  Sandalwood_Spice
# 39333       2024-03-06           60324062.0       Liquid  Cedarwood_Forest
# 39334       2024-03-06           60324063.0       Liquid     Citrus_Breeze
# 39335       2024-03-06           60324063.0       Liquid  Sandalwood_Spice
# 39336       2024-03-06           60324064.0          Bar        Fresh_Rain
#
#         Size  Cash or Card  Loyalty Number    Customer Name Loyalty Tier  \
# 0      0.25L           2.0       1005245.0  Laurens Squibbs       Bronze
# 1       0.5L           2.0       1005245.0  Laurens Squibbs       Bronze
# 2         1L           1.0       1007270.0     Cary Breckon       Bronze
# 3      0.25L           2.0       1009750.0      Orv Drewitt       Bronze
# 4         1L           2.0       1009750.0      Orv Drewitt       Bronze
# ...      ...           ...             ...              ...          ...
# 39332     4x           2.0       1001139.0     Jae Swindall       Bronze
# 39333  0.25L           2.0       1001139.0     Jae Swindall       Bronze
# 39334   0.5L           1.0       1007693.0      Rheba Roark       Bronze
# 39335   0.5L           1.0       1007693.0      Rheba Roark       Bronze
# 39336     4x           1.0       1007047.0  Sashenka Marchi       Silver
#
#        Loyalty Discount  Quantity  Sales Before Discount  \
# 0                  0.05       2.0                   8.50
# 1                  0.05       2.0                  14.70
# 2                  0.05       1.0                  13.19
# 3                  0.05       2.0                   9.00
# 4                  0.05       3.0                  39.81
# ...                 ...       ...                    ...
# 39332              0.05       4.0                  31.96
# 39333              0.05       5.0                   7.80
# 39334              0.05       1.0                   2.48
# 39335              0.05       5.0                  47.80
# 39336              0.10       5.0                  21.40
#
#        Sales After Discount   Profit
# 0                    8.0750   3.1750
# 1                   13.9650   2.0250
# 2                   12.5305   2.8605
# 3                    8.5500   4.0100
# 4                   37.8195  10.9395
# ...                     ...      ...
# 39332               30.3620   1.0020
# 39333                7.4100   0.7600
# 39334                2.3560   0.5660
# 39335               45.4100  21.0600
# 39336               19.2600   2.3600
#
# [39337 rows x 14 columns]
